# %% [markdown]
# # Ray tracing and visualization basics
#
# The goal of this example is to show how to perform a very simple ray-tracing of a generic shape and visualize the results.
#
# In this example we will show how to compute the interaction between the impinging rays and the shape accounting for specular reflection and diffusion.
#
# We will also show how to determine which parts of the shape are impinged by the first, second, third, .., reflections and represent it graphically.
#
# Note: Since here we want to show very basic functionalities of the library, we will use directly the core utilities, without using the more complex classes (Spacecraft, PixelPlane, etc.).
#
# **Note**: It is better to run this example rather than just reading the pdf version of this notebook. This way you'll be able to explore the 3D plots.

# %%
import trimesh as tm
import numpy as np
import spiceypy as sp
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.lines import Line2D

from pyRTX.classes.PixelPlane import PixelPlane
from pyRTX.core import utils_rt
from pyRTX.visual.utils import color_convert, plot_mesh

# %% [markdown]
# We can apply the same example to different shapes. Choose here below which one

# %%
obj = 'Annulus'
#obj = 'Sphere'

# %%
if obj == 'Annulus':
    mesh = tm.creation.annulus(0.5,1,height = 0.5)
elif obj == 'Sphere':
    mesh = tm.creation.icosphere(radius = 1, subdivisions = 4)

# %% [markdown]
# Let's set up the origin of the ray-tracing rays. We set up the so-called Pixel Plane at a certain RA/DEC (or lat/lon) with respect to the base reference frame.
# The PixelPlane object method `.dump()` returns the origin coordinates and directions of the ray tracing rays. Note that the basic length unit used in pyRTX is the `km`

# %%
RA = 0
DEC = 10*np.pi/180

pixelPlane = PixelPlane(
        spacecraft = 'None',
        mode = 'Fixed',
        distance = 3,
        width = 2,
        height = 2,
        ray_spacing = 0.01,
        lon = RA,
        lat = DEC,
        units = 'km',
)
        

ray_origins, ray_directions = pixelPlane.dump()

# %% [markdown]
# We can use these points/directions as the input of the ray tracer.
#
# Here we set the options of the ray tracer:
#
# - number of reflections
# - diffusion activated/not activated
# - ray tracing kernel (it can be either "Native", "Embree" or "Embree 3"
#
#
# `utils_rt.RTXkernel()` returns:
# - index_tri_container : an array of arrays containing the indexes of the mesh vertices that have been hit by the tracing rays. if more than one bounce is computed then, the array will be structured as follows [ [indexes_bounce_1], [indexes_bounce_2],...]
# - index_ray_container : an array of arrays containing the indexes of the rays that have hit the mesh.
# - locations_container : an array of arrays containing the coordinates of the hit points
# - ray_directions_container :  an array containing the direction unit vectors of the reflected rays
# - diffusion pack: a container with the information on the diffused rays. This will be discussed separately in another tutorial

# %%
result = utils_rt.RTXkernel(
    
    
    mesh,              # Mesh object
    ray_origins,       # Coordinates of the origins of the tracing rays
    ray_directions,    # Directions of the tracing rays
    kernel = 'Embree', # Ray tracing kernel (see documentation)
    bounces = 2,       # Number of reflections to compute
    diffusion = True,  # Compute the diffused rays after the first reflection?
    num_diffuse = 10   # Number of diffused rays for each diffusion point
                                                                            
)

index_tri_container = result[0]
index_ray_container = result[1] 
locations_container = result[2]
ray_origins_container = result[3]
ray_directions_container = result[4]
diffusion_pack = result[5]

# %% [markdown]
# Visualize the impinging rays and the hit surfaces.
#
# We first set the colors of the various entities:

# %%
base_mesh_color = 'green'
hit_faces_colors = 'red'
second_hit_faces = 'pink'
reflected_rays_color = 'orange'
rays_color = 'gold'
subsampling = 10 # Sub-sampling of the pixel plane rays just for making the visualization process faster
ray_length = 1.0 # Length of the rays in the plot
mesh.unmerge_vertices() # This avoids automated shading

# %% [markdown]
# Let's visualize first the incoming rays (which could be e.g., the sun rays) in yellow and the portion of the mesh hit by the rays in red.

# %%
# First bounce
bounce = 0

# Impinging rays
ray_origins_sub = ray_origins[::subsampling]
ray_directions_sub = ray_directions[::subsampling]


# Mesh visualization
mesh.visual.face_colors = color_convert(base_mesh_color, size = len(mesh.faces))
mesh.visual.face_colors[index_tri_container[bounce]] = color_convert(hit_faces_colors)


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection = '3d')
ax = plot_mesh(mesh,ax=ax)
for i in range(len(ray_origins_sub)):
    ax.plot(
        [ray_origins_sub[i,0], ray_origins_sub[i,0] + ray_directions_sub[i,0]*ray_length],
        [ray_origins_sub[i,1], ray_origins_sub[i,1] + ray_directions_sub[i,1]*ray_length],
        [ray_origins_sub[i,2], ray_origins_sub[i,2] + ray_directions_sub[i,2]*ray_length],
        color = rays_color
    )
plt.show()

# %% [markdown]
# Now let's visualize the second bounce (in pink) and the first-order reflected rays (in orange).

# %%
bounce = 1
ray_length = 0.5

# Reflected rays
ray_origins_sub = ray_origins_container[bounce][::subsampling]
ray_directions_sub = ray_directions_container[bounce][::subsampling]

# Mesh visualization
mesh.visual.face_colors = color_convert(base_mesh_color, size = len(mesh.faces))
mesh.visual.face_colors[index_tri_container[bounce]] = color_convert(second_hit_faces)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')
ax = plot_mesh(mesh, ax = ax)
for i in range(len(ray_origins_sub)):
    ax.plot(
        [ray_origins_sub[i,0], ray_origins_sub[i,0] + ray_directions_sub[i,0]*ray_length],
        [ray_origins_sub[i,1], ray_origins_sub[i,1] + ray_directions_sub[i,1]*ray_length],
        [ray_origins_sub[i,2], ray_origins_sub[i,2] + ray_directions_sub[i,2]*ray_length],
        color=reflected_rays_color
    )
plt.show()
